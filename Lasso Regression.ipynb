# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import math
import seaborn as sns
import sklearn
from sklearn import linear_model
from sklearn import preprocessing
# %matplotlib inline
sns.set_style('white')

# Suppress annoying harmless error.
import warnings
warnings.filterwarnings(action="ignore", module="scipy", message="^internal gelsd")

# %% [markdown]
# Ridge regression shrinks parameter estimates, but the estimates never reach exactly 0.  **LASSO** (Least Absolute Shrinkage and Selection Operator), on the other hand, is a model optimization mechanic that works by trying to force small parameter estimates to be equal to zero, effectively dropping them from the model.  This can prevent overfitting, and also works as an embedded feature selection method.  Lasso is extremely handy when you are dealing with thousands or hundreds of thousands of predictors and need to optimize processor time, or when you want to arrive at a simpler solution that is easier to interpret.
#
# The cost function to minimize for lasso is _very similar_ to the cost function minimized for ridge. Can you spot the difference?
#
# $$\sum_{i=1}^n(y_i-(\alpha+\beta x_i))^2+\lambda\sum_{j=1}^p|\beta_j| $$
#
# The difference is that rather than penalizing by the sum of *squared* coefficients as ridge does, lasso penalizes by the sum of the *absolute values* of the coefficients.  This means the penalty doesn't increase as swiftly with coefficient size.  Regularization based on the sum of the absolute weights is also called "**L1 regularization**".
#
# Why would penalizing with the sum of the absolute values of coefficients lead to a solution with zero estimates for some parameters, while penalizing with the sum of the squares of coefficients does not?  It all comes down to derivatives.
#
# We encountered derivatives briefly during an earlier assignment on the gradient descent algorithm.  You may recall that a partial derivative represents the sensitivity of one quantity to changes in another quantity.  In the case of both ordinary least squares regression and ridge regression, the derivative used to find the optimal solution is the partial derivative of the cost function relative to the coefficients in $\beta$:
#
# $$\frac{\partial}{\partial\beta}$$
#
# Unfortunately, that won't work for lasso. While we can calculate a derivative for most of the values of $x$ in lasso, there is no derivative where $x=0$.  You can imagine this as our multi-dimensional surface made up of gradients having a big hole in it (the technical term for the hole is a "*discontinuity*"). If the gradient descent algorithm calculates a value that falls in the "hole", it has no idea where to go next.  The model "fails to converge". In other words, it fails to arrive at an optimal solution.

# %% [markdown]
# # Fitting Lasso: Coordinate Descent Algorithm
#
# Since basing modeling strategy on a surface with a hole in it is obviously not ideal, lasso regression models are optimized using a coordinate descent algorithm rather than a gradient descent algorithm.  Coordinate descent works like this:
#
# Pick some starting values for $\beta$, often $\beta=0$.
#
# For each feature $j$ in $\beta$:
# * Predict the outcome using all features except for $j$.
# * Look at how the residuals from the model using $\beta_{-j}$ (all betas except $j$) correlate with feature $j$. This correlation is called $\rho_j$.
# * If the correlation falls within an area enclosing 0 defined by $\lambda$, set $\beta_j=0$. (called *soft threshholding*)
# * If $\rho_j < \frac{\lambda}2$ set $\beta_j$ equal to $\rho_j + \frac{\lambda}2$
# * If $\rho_j > \frac{\lambda}2$ set $\beta_j$ equal to $\rho_j - \frac{\lambda}2$
#
# This will iterate through all features 1 through $j$ on each cycle, then begin again.  Alternatively, the algorithm can be set to choose to exclude a feature at random each iteration, rather than cycling through all features.  Each time a feature is checked, it will shrink a bit from the previous time (unless the feature is already set to 0, in which case it will remain 0).
#
# Continue until the maximum difference between parameter estimates in the previous cycle and the current cycle is less than a pre-determined threshold $tol$.  For SKlearn, $tol$ defaults to 0.0001.
#
# To summarize: Lasso works by iteratively fitting a model to the data while excluding one of the features.  It then checks how well the model reproduces the data, and if the model fit is good enough (with "good enough" determined by $\lambda$) then the excluded feature is deemed unnecessary and its $\beta$ is set to zero, effectively excluding it from the model. Otherwise, the excluded feature's $\beta$ is set using a combination of the correlation of the feature with the model residuals ($\rho_j$) and $\frac{\lambda}2$ and a new iteration begins, using the newly-computed $\beta$ for the previously-excluded feature and excluding a new feature.  This continues until the change in $\beta$ is less than a pre-determined threshold.
#
# Hopefully this demonstrates how lasso can both create overfitting-protection through shrinkage and create sparsity (many parameters set to 0) through feature selection.  Let's see it at work, using the same dataset as previously.

# %%
# Load the data again. Keep air quality data, drop the index column
# and any missing data columns.
df = pd.read_csv(
    'https://vincentarelbundock.github.io/Rdatasets/csv/ISLR/Default.csv'
).iloc[:,1:].dropna()

# Recode strings to numeric.
df['default'] = np.where(df['default']=='Yes', 1, 0)
df['student'] = np.where(df['student']=='Yes', 1, 0)
names = df.columns
df = pd.DataFrame(preprocessing.scale(df), columns=names)

# Define the training and test sizes.
trainsize = int(df.shape[0] / 2)
df_test = df.iloc[trainsize:, :].copy()
df_train = df.iloc[:trainsize, :].copy()

Y_train = df_train['income'].values.reshape(-1, 1)
X_train = df_train.loc[:, ~(df_train.columns).isin(['income'])]

# Make some new features to capture potential quadratic and cubic
# relationships between solar radiation and day or temperature.
df_train['balance_student'] = df_train['balance'] * df_train['student']
df_train['balance_default'] = df_train['balance'] * df_train['default']
df_train['student_default'] = df_train['student'] * df_train['default']
df_train['balance_sqrt'] = (df_train['balance'] + 100) ** .5
df_train['balance2'] = (df_train['balance'] + 100) ** 2
df_train['balance3'] = (df_train['balance'] + 100) ** 3

X_train2 = df_train.loc[:, ~(df_train.columns).isin(['income'])]

# Test the simpler model with smaller coefficients.
Y_test = df_test['income'].values.reshape(-1, 1)
X_test = df_test.loc[:, ~(df_test.columns).isin(['income'])]

# Test the more complex model with larger coefficients.
df_test['balance_student'] = df_test['balance'] * df_test['student']
df_test['balance_default'] = df_test['balance'] * df_test['default']
df_test['student_default'] = df_test['student'] * df_test['default']
df_test['balance_sqrt'] = (df_test['balance'] + 100) ** .5
df_test['balance2'] = (df_test['balance'] + 100) ** 2
df_test['balance3'] = (df_test['balance'] + 100) ** 3
X_test2 = df_test.loc[:, ~(df_test.columns).isin(['income'])]
# Out:
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:11: DataConversionWarning: Data with input dtype int32, float64 were all converted to float64 by the scale function.
#   # This is added back by InteractiveShellApp.init_path()

# %%
# Small number of parameters.
lass = linear_model.Lasso(alpha=.35)
lassfit = lass.fit(X_train, Y_train)
print('R² for the model with few features:')
print(lass.score(X_train, Y_train))
origparams = np.append(lassfit.coef_, lassfit.intercept_)
print('\nParameter estimates for the model with few features:')
print(origparams)

# Large number of parameters.
lassBig = linear_model.Lasso(alpha=.35)
lassBig.fit(X_train2, Y_train)
print('\nR² for the model with many features:')
print(lassBig.score(X_train2, Y_train))
origparams = np.append(lassBig.coef_, lassBig.intercept_)
print('\nParameter estimates for the model with many features:')
print(origparams)
# Out:
# R² for the model with few features:
# 0.4500625793011847
#
# Parameter estimates for the model with few features:
# [-0.         -0.40657726 -0.          0.00114596]
#
# R² for the model with many features:
# 0.44363376712897057
#
# Parameter estimates for the model with many features:
# [ 0.00000000e+00 -3.89351238e-01  0.00000000e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00 -2.77688887e-04
#  -7.09158792e-07  3.48711577e+00]

# %% [markdown]
# Checking predictive power using the test set:

# %%
print(lass.score(X_test, Y_test))

print(lassBig.score(X_test2, Y_test))
# Out:
# 0.44553225151184195
# 0.4380466345914472

# %% [markdown]
# ## Regularization parameter: Lasso
#
# The $\lambda$ for lasso can var between 0 (no penalty, acts like OLS) and infinity.  If $\lambda$ is too large, all parameters will be set to zero.
#
# Create a plot below of how $R^2$ varies across different values of $\lambda$ for ridge and lasso regression. Use logic and code similar to the ridge regression demonstration above, and base your plot on the X_train2 feature set.
#
# Do lasso and ridge yield the same $R^2$ for a given lambda value?
#
# Submit your work and discuss the results with your mentor.

# %%
# Your code here
# Store estimates.
alpha_val = list(np.arange(0.1,1,.001))

# Storing legend information.
ridge = []
lasso = []

#Run the model for many alphas.
for alpha in alpha_val:
    ridgeBig = linear_model.Ridge(alpha=alpha, fit_intercept=False)
    ridgeBig.fit(X_train2, Y_train)
    ridge.append(ridgeBig.score(X_train2, Y_train))
    lassBig = linear_model.Lasso(alpha=alpha)
    lassBig.fit(X_train2, Y_train)
    lasso.append(lassBig.score(X_train2, Y_train))
    
plt.plot(alpha_val, ridge, label = 'Ridge')
plt.plot(alpha_val, lasso, label = 'Lasso')
plt.legend()
plt.show()
# Out:
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.828186e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.846529e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.864873e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.883219e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.901565e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.919913e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.938262e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.956612e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.974964e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.993316e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.011670e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.030024e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.048380e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.066737e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.085095e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.103455e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.121815e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.140177e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.158539e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.176903e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.195268e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.213634e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.232001e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.250370e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.268739e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.287110e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.305482e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.323855e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.342228e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.360604e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.378980e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.397357e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.415736e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.434115e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.452496e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.470878e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.489261e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.507645e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.526030e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.544416e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.562803e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.581192e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.599581e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.617972e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.636364e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.654757e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.673151e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.691546e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.709942e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.728339e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.746737e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.765137e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.783537e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.801939e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.820341e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.838745e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.857150e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.875556e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.893963e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.912371e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.930780e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.949190e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.967602e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.986014e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.004428e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.022842e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.041258e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.059674e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.078092e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.096511e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.114931e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.133351e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.151773e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.170196e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.188621e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.207046e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.225472e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.243899e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.262327e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.280757e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.299187e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.317619e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.336051e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.354485e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.372919e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.391355e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.409791e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.428229e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.446668e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.465108e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.483548e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.501990e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.520433e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.538877e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.557322e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.575768e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.594215e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.612663e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.631112e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.649562e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.668013e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.686465e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.704919e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.723373e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.741828e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.760284e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.778741e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.797200e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.815659e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.834119e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.852580e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.871043e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.889506e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.907970e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.926435e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.944902e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.963369e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number3.981837e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.000307e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.018777e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.037248e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.055721e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.074194e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.092668e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.111143e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.129620e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.148097e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.166575e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.185054e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.203535e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.222016e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.240498e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.258981e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.277465e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.295950e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.314437e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.332924e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.351412e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.369901e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.388391e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.406882e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.425374e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.443867e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.462361e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.480855e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.499351e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.517848e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.536346e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.554845e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.573344e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.591845e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.610347e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.628849e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.647353e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.665857e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.684363e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.702869e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.721376e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.739885e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.758394e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.776904e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.795415e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.813927e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.832440e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.850954e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.869469e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.887985e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.906502e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.925020e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.943538e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.962058e-17
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.980579e-17
#   overwrite_a=True).T
# ...
# Reciprocal condition number1.003070e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.004944e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.006818e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.008692e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.010566e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.012440e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.014314e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.016188e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.018063e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.019937e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.021812e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.023686e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.025561e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.027435e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.029310e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.031185e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.033060e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.034934e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.036809e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.038684e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.040560e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.042435e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.044310e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.046185e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.048061e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.049936e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.051812e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.053687e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.055563e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.057439e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.059314e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.061190e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.063066e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.064942e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.066818e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.068694e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.070570e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.072447e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.074323e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.076199e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.078076e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.079952e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.081829e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.083705e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.085582e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.087459e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.089336e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.091212e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.093089e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.094966e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.096843e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.098721e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.100598e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.102475e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.104352e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.106230e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.108107e-16
#   overwrite_a=True).T
# c:\users\bharath\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.109985e-16
#   overwrite_a=True).T

# %% [markdown]
# Lasso reduces the R2 value, however this is due to its technique of feature exclusion to reduce overfitting
